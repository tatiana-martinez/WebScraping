# %%
1. Go to Sarenza/Select a page and find URL or API 
Filtre in webpage : Titre, Name of pictures, Brand Name, Name of the shoes, the price of the shoes
2. Check the status and apply the error handling functions
3. Use Beautiful Soup to get a soup or flat function in case of API:
4. Convert into a Dataframe Panda
5. Export into DataBase SQL or in a CSV file
6. Bonus: Clean the data -> Aggregate data/Make Stats

# %%
def headers():
    headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: akaas_RunningPageListe=1631097118~rv=38~id=80e6111f1a2a09d1974768ce5bad4449; s_rcp=%7B%22Audience%22%3Atrue%2C%22Marketing%22%3Atrue%2C%22Social%22%3Atrue%7D; _ga=GA1.2.580294557.1599577960; _gcl_au=1.1.95106946.1599577961; cikneeto_uuid=id:7948053a-e450-41ef-bd18-3b7635884853; _cs_c=1; __ywtfpcvuid=42739791461599577961951; rlvt_tmpId=ckeu3f2m400003g5llgf8th35; _fbp=fb.1.1599577962084.42249191; _hjid=c930c9e7-7e93-4af1-ae38-023f2d9a7503; mics_vid=9585469677; mics_lts=1599577962866; __utmv=1.|1=Monitoring_rank=160630_Ranking_ABCTest_VarC=1; s_prefgender=1; s_https=true; __utmc=1; __utmz=1.1599685794.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); _gid=GA1.2.902583650.1599685794; htk_sarenza_fr_visit=84ieqyg575bm; _hjTLDTest=1; s_amg=1; eb-lastactivity-hash=972180865; eb-profile-cluster=20; eb-profile-clusters={%225aec482e70c9c62fc11050dd%22:{%221599444467177%22:6%2C%221599272542744%22:20}}; s_ano=jX8Age95sEC6Tt53N4ZNvdZaE5I1QuzOtnZeYtD-lguCggfqJ8yNwJwUw9pT2qjTxtoYUG8vz41_huB4uTSgdA2; __utma=1.580294557.1599577960.1599689951.1599739389.4; _hjIncludedInSessionSample=1; _hjAbsoluteSessionInProgress=0; __ywtfpcsuid=31948292151599739390715; htk_sarenza_fr_chat_widget_shrinked=1; htk_sarenza_fr_chat_widget_state=shrinked; htk_sarenza_fr_first_visits=1101000000; dtCookie=v_4_srv_3_sn_C92138412601B8F70BBEAF6685D628F6_perc_100000_ol_0_mul_1; eb-profile=bd7d8839-cfd5-44a1-b1ed-b54e11c7b96f:3938:1599743821883; etuix=qkySTvcLbkXS3KkJ6he._XZUU6qzc8Yhe5ySVWu8apkA0lhtb6vj.A--; _cs_id=a2708dc1-71ae-a0d1-8188-0fafdfc5bcf3.1599577961.7.1599746247.1599739389.1.1633741961441.Lax.0; _cs_s=10.1; cto_bundle=B2-u419JNGFKN1d5dmFFeXQlMkJnZXhUZ3NJJTJGTEgyV3JpRGlWY0E1dVFjWlhaNGczRTV4ZGxyaCUyRlJLNEFwJTJCTyUyQjYwTHkyTko0eUg5TzRlMEl2SXQxVFpyOUVLZGIlMkJWakJlb2Q5ZnZ0aFZSanpURzBYdmpOZUgwblY2VjdKYlViR0xzOEg1aWRmSFBrMzhYR2UxSTlXVTFjQTZkR0ElM0QlM0Q; __utmb=1.35.9.1599746269914; cikneeto=date:1599746270869; _uetsid=3054fc56a449028f781d453da7edc438; _uetvid=f9d1da9ca2e7448279089c583422383b; _gat_UA-99688628-1=1
pragma: no-cache
referer: https://www.sarenza.com/store/product/gender-type/list/view?color=2&gender=1&material=559&material=591&material=790&material=80&sub_type=4&sub_type=6&sub_type=6&type=76
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"""
    
    headers=dict(i.split(': ') for i in headers.split('\n'))
    
    return(headers)

# %%
headers()
# Out:
# {'accept': '*/*',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
#  'cache-control': 'no-cache',
# ...

# %%
url='https://www.sarenza.com/store/product/gender-type/list/get?color=2&gender=1&material=559&material=591&material=790&material=80&sub_type=4&sub_type=6&sub_type=6&type=76&index=400&count=100'

# %%
##error handling > to adapt
def func(url, headers={}):
    import requests as r
    resp=r.get(url, headers=headers)
    if resp:
        return resp.content
    else:
        print('Sorry, there is an error', resp.status_code,'somewhere')
        return None

#################
from requests.exceptions import SSLError, Timeout, TooManyRedirects, RequestException
from contextlib import closing
from IPython.display import Markdown, display
import warnings
warnings.filterwarnings('ignore')
timeout_glob=0.05
verify_glob=True
allow_glob=False
def printmd(string):
    display(Markdown('**'+string+'**'))
def is_good_response(x):
    """
    Returns True if the response seems to be an HTML, False otherwise
    x is response
    """
    content_type=x.headers['Content-Type'].lower()
    return ((x.status_code==200 and content_type is not None and content_type.find('html')>1), x.status_code)
def log_error(e):
    print(e)
def status_handler(status):
    if status<300:
        print('Alles gut!')
    elif status>=400 and status<500:
        print('request has failed due to you mistake bro. Check the link, headers, server and whether you have an access to this page.')
    else:
        print('Yoooo, I have no clue what has happened. But you are stuck, since you didnt receive any output from server')
    return None
def adaptive_scraping(url, timeout=timeout_glob, verify=verify_glob):
    global timeout_glob
    global verify_glob
    global allow_glob
    import requests as r
    try:
        with closing(r.get(url, stream=True, timeout=timeout_glob, verify=verify_glob, allow_redirects=allow_glob)) as resp:
            test1=is_good_response(resp)
            print(resp)
            if test1[0]:
                return resp.content
            else:
                return status_handler(test[1])
    except Timeout as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can increase response waiting time. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            timeout_glob*=2
            return adaptive_scraping(url)
        else:
            return None
    except SSLError as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can skip verification test. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            verify_glob=False
            return adaptive_scraping(url)
        else:
            return None
    except TooManyRedirects as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('We can increase the number of allowed redirects. Do you want to continue?')
        ans=input('\n[Yes|No]\t')
        if ans.lower()=='yes':
            allow_glob=True
            return adaptive_scraping(url)
        else:
            return None
    except RequestException as e:
        log_error(f'Error during request to {url}: {str(e)}')
        printmd('Unfortunately, we have no clue what to do.  Please try again later. ')
        return None

# %%
func(url=url, headers=headers())
# Out:
# b'{"SearchQuery":"fh_location=//catalog01/fr_FR/globalvisibility=1/luxe>{0;1}/material>{559;591;790;80}/multigender=1/pays=fr/sarenzacolor>{2}/subtype>{4;6}/type>{76}&fh_view_size=100&fh_start_index=400&application=website&ABPageRanking=C","ProductCount":417,"ProductVignetteList":[{"ProductColorId":289346,"ProductColorUri":"/senso-alannah-s846634-br1307-t84-p0000151840","ThumbUri":"https://cdn.sarenza.net/_img/productsv4/0000151840/0000151840_289346_09_504x690.jpg?201812211523&v=20180830155342","ColorName":null,"IsLazy":false,"ModelName":"Alannah","BrandName":"SENSO","IsNew":false,"IsAvailable":false,"IsDangerous":false,"HasInitialDiscount":false,"FormatedInitialDiscount":"0 %","HasDiscount":true,"FormatedDiscount":"-50 %","HasSlashedPrice":true,"ShowSaving":true,"Saving":99.5000,"FormatedSlashedPrice":"199,00 \xe2\x82\xac","HasMultiplePrice":false,"FormatedSellingPrice":"99,50 \xe2\x82\xac","Stock":{"ProductColorId":289346,"IsOutOfStock":false,"InStockVariantList":[{"VariantId":2018
# ...

# %%
def getproduct():
    import time
    from pandas import json_normalize
    import requests as r
    import pandas as pd
    

    final_data = pd.DataFrame()
    for k in range(4): ## Since, I want to fetch data for 4 pages
        response = r.get(f'https://www.sarenza.com/store/product/gender-type/list/get?color=2&gender=1&material=559&material=591&material=790&material=80&sub_type=4&sub_type=6&sub_type=6&type=76&index={k}*100&count=100', headers=headers())
        result = response.json()
        flat_data = json_normalize(result)
        flat_data1 = json_normalize(flat_data['ProductVignetteList'][0])
        final_data = final_data.append(flat_data1)
        
        #time.sleep(1) ## Here I'm asking my code to wait for 1 second after every request.
        
    return(final_data)

# %%
getproduct()
# Out:
#     ProductColorId                                    ProductColorUri  \
# 0           473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 1           456529  /no-name-arcade-straps-print-python-s779877-br...
# 2           449598  /pataugas-julia-mix-f4f-s1707-br226-t76-p00002...
# 3           449595  /pataugas-bono-n-f4e-s751232-br226-t76-p000024...
# 4           472422  /skechers-d-lites-freeze-talk-w-s812718-br278-...
# ..             ...                                                ...
# 95          447926  /vagabond-shoemakers-judy-5024-s332-br577-t76-...
# 96          459775  /caterpillar-intruder-w-s332-br54-t76-p0000226744
# 97          451196        /bronx-san-sai-s791885-br42-t76-p0000241241
# 98          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 99          453882  /mephisto-patsy-shiny-s332-br1047-t76-p0000242755
#
#                                              ThumbUri ColorName  IsLazy  \
# ...

# %%
#dfproduct=getproduct()
#productstock=dfproduct.loc[dfproduct["Stock.InStockVariantList"].dropna().index].copy()

# %%
#from pandas import json_normalize
#list_of_jsons=productstock.apply((lambda x: [{j:k for j,k in list(i.items())+[("ProductColorId",x["ProductColorId"])]} 
#                        for i in x["Stock.InStockVariantList"]]), axis=1).tolist()

#json_normalize([j for i in list_of_jsons for j in i])

# %%
def stock():
    from pandas import json_normalize
    
    dfproduct=getproduct()
    
    productstock=dfproduct.loc[dfproduct["Stock.InStockVariantList"].dropna().index].copy()
    
    list_of_jsons=productstock.apply((lambda x: [{j:k for j,k in list(i.items())+[("ProductColorId",x["ProductColorId"])]} 
                        for i in x["Stock.InStockVariantList"]]), axis=1).tolist()
    
    return(json_normalize([j for i in list_of_jsons for j in i]))

# %%
stocks = stock()
stocks = stocks.to_csv(r'/Users/tatiana/ironhack/WebScraping/stock.csv', index=False)

# %%
def mergeproductstock():
    import pandas as pd
    import time

    stock()
    stocks=stock()
    #time.sleep(5)
    #print('ok df stock')
    pd.merge(dfproduct,stocks,on='ProductColorId')
    print('ok df merge')
    
    Product_stock = pd.merge(dfproduct,stocks,on='ProductColorId')
    return(Product_stock)

# %%
mergeproductstocks= mergeproductstock()
# Out:
# ok df stock
# ok df merge

# %%
#send mergeproductstock to a csv file
mergeproductstocks = mergeproductstocks.to_csv(r'/Users/tatiana/ironhack/WebScraping/mergeproductstock.csv', index=False)
# Out:
# ok df stock
# ok df merge

# %%
dfproduct.columns.values
# Out:
# array(['ProductColorId', 'ProductColorUri', 'ThumbUri', 'ColorName',
#        'IsLazy', 'ModelName', 'BrandName', 'IsNew', 'IsAvailable',
#        'IsDangerous', 'HasInitialDiscount', 'FormatedInitialDiscount',
#        'HasDiscount', 'FormatedDiscount', 'HasSlashedPrice', 'ShowSaving',
#        'Saving', 'FormatedSlashedPrice', 'HasMultiplePrice',
#        'FormatedSellingPrice', 'MarketingOperationPictoUrl',
#        'MarketingOperationPictoName', 'HasMarketingOperationPicto',
#        'FromLocation', 'VariantList', 'HasMoreThanOneVariant',
#        'HasStockMessage', 'IsOutOfStock', 'StockMessage',
#        'HasSupplierSellingPrice', 'FormatedSupplierSellingPrice',
#        'Stock.ProductColorId', 'Stock.IsOutOfStock',
#        'Stock.InStockVariantList', 'Stock.DisplaySizes',
#        'Stock.HasManySizes', 'Stock.SizesTitle'], dtype=object)

# %%
def connexion_db():
    import pandas as pd
    import pymysql
    from sqlalchemy import create_engine
    from getpass import getpass
    from sqlalchemy import inspect

    import os
    
    print('please insert your password:')
    username='root'
    password=getpass()
    engine=create_engine(f'mysql+pymysql://{username}:{password}@localhost/Sarenza')
    print('connection : ok')
    pass

# %%
connexion_db()
# Out:
# please insert your password:
# ········
# connection : ok

# %%
def get_tables_db():
    inspector=inspect(engine)
    return (inspector.get_table_names())

# %%
get_tables_db()
# Out:
# ['Sarenza.productstocks', 'Sarenza.stocks']

# %%
def mergeprodstock_tosql():
    import pandas as pd
    import time
    
    df= mergeproductstock()
    df1= df.drop(columns='Stock.InStockVariantList')
    df1.to_sql('mergeproductstocks',con=engine, if_exists='replace', index=False)
    pass

# %%
mergeprodstock_tosql()
# Out:
# ok df stock
# ok df merge

# %%
#mergeproductstocks= mergeproductstock()
#mergeproductstock= mergeproductstock().drop(columns='Stock.InStockVariantList')
#mergeproductstock.to_sql('mergeproductstocks',con=engine, if_exists='replace', index=False)

# %%
def stock_tosql():
    stocks= stock()
    stocks.to_sql('stocks', engine, if_exists='replace', index=False)
    pass

#stocks= stock()
#stocks.to_sql('Sarenza.stocks', engine, if_exists='replace', index=False)

# %%
stock_tosql()

# %%
def product_tosql():

    dfproduct=getproduct()#
    productnostock=dfproduct.drop(columns='Stock.InStockVariantList')#
    
    productnostock.to_sql('product',con=engine, if_exists='replace', index=False)
    pass

# %%
product_tosql()
#productnostock.to_sql('product',con=engine, if_exists='replace', index=False)

# %%
#productnostock=dfproduct.drop(columns='Stock.InStockVariantList')
#productnostock
df= mergeproductstock()
df1= df.drop(columns='Stock.InStockVariantList')
df1
# Out:
# ok df stock
# ok df merge
#        ProductColorId                                    ProductColorUri  \
# 0              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 1              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 2              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 3              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 4              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# ...               ...                                                ...
# 35259          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35260          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35261          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35262          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35263          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
#
# ...

# %%
df1.count()
# Out:
# ProductColorId                  35264
# ProductColorUri                 35264
# ThumbUri                        35264
# ColorName                           0
# IsLazy                          35264
# ModelName                       35264
# BrandName                       35264
# IsNew                           35264
# IsAvailable                     35264
# IsDangerous                     35264
# HasInitialDiscount              35264
# FormatedInitialDiscount         35264
# HasDiscount                     35264
# FormatedDiscount                35264
# HasSlashedPrice                 35264
# ShowSaving                      35264
# Saving                              0
# FormatedSlashedPrice            35264
# HasMultiplePrice                35264
# FormatedSellingPrice            35264
# MarketingOperationPictoUrl          0
# MarketingOperationPictoName         0
# HasMarketingOperationPicto      35264
# FromLocation                    35264
# VariantList                         0
# ...

# %%
#only black sneakers for female
productstockdrop=df1.drop(columns=['ColorName','Saving','MarketingOperationPictoUrl','MarketingOperationPictoName',
                             'VariantList','StockMessage','FormatedSupplierSellingPrice']);

# %%
productstockdrop
# Out:
#        ProductColorId                                    ProductColorUri  \
# 0              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 1              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 2              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 3              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# 4              473057  /geox-d-myria-d6468a085-s332-br111-t76-p000025...
# ...               ...                                                ...
# 35259          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35260          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35261          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35262          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
# 35263          456745      /puma-rise-mono-s893410-br245-t76-p0000244439
#
#                                                 ThumbUri  IsLazy  \
# ...

# %%
productstockdrop.count()
# Out:
# ProductColorId                35264
# ProductColorUri               35264
# ThumbUri                      35264
# IsLazy                        35264
# ModelName                     35264
# BrandName                     35264
# IsNew                         35264
# IsAvailable                   35264
# IsDangerous                   35264
# HasInitialDiscount            35264
# FormatedInitialDiscount       35264
# HasDiscount                   35264
# FormatedDiscount              35264
# HasSlashedPrice               35264
# ShowSaving                    35264
# FormatedSlashedPrice          35264
# HasMultiplePrice              35264
# FormatedSellingPrice          35264
# HasMarketingOperationPicto    35264
# FromLocation                  35264
# HasMoreThanOneVariant         35264
# HasStockMessage               35264
# IsOutOfStock_x                35264
# HasSupplierSellingPrice       35264
# Stock.ProductColorId          35264
# Stock.IsOutOfStock            35264
# ...

# %%
def productstockdrop_tosql():
    productstockdrop.to_sql('product',con=engine, if_exists='replace', index=False)
    pass
